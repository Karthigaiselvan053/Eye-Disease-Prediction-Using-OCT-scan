# %%
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
import numpy as np
import os

# %%
model = tf.keras.models.load_model(
    "Trained_Model.h5",
    custom_objects={'F1Score': tfa.metrics.F1Score}
)

# %%
img_path = './test/DRUSEN/DRUSEN-1112835-7.jpeg'
img = tf.keras.utils.load_img(img_path, target_size=(224, 224))
x = tf.keras.utils.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 7s 7s/step

# %%
preds
# Out:
# array([[0.2082331 , 0.04732145, 0.66047347, 0.08397199]], dtype=float32)

# %%
class_name = os.listdir("./test")
class_name
# Out:
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
result_index = np.argmax(preds)
class_name[result_index]
# Out:
# 'DRUSEN'
